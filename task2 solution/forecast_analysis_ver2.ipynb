# %% [markdown]
# ### Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import datetime as dt

# %%
#import campnew data as dataframe
campnew=pd.read_csv('..\clean_data\campnew.csv')
campnew['date']=pd.to_datetime(campnew['date'], format='%d/%m/%Y')
print("date range is: ", campnew.date.min(), campnew.date.max())
# Out:
# date range is:  2018-09-17 00:00:00 2018-10-04 00:00:00

# %%
campnew=campnew.set_index('date')

# %% [markdown]
# ### EDA

# %%
fig = plt.figure()
plt.subplots_adjust(hspace=0.4)

ax1 = fig.add_subplot(111)
#ax2 = fig.add_subplot(312)#
#ax3 = fig.add_subplot(313)

campnew.groupby(campnew.index)['impressions'].sum().plot(kind='line', ax=ax1, figsize=(20,5), legend = True)
campnew.groupby(campnew.index)['clicks'].sum().plot(kind='line', ax=ax1, figsize=(20,5), legend = True)
campnew.groupby(campnew.index)['conversions'].sum().plot(kind='line',ax=ax1, figsize=(20,5), legend = True)
campnew.groupby(campnew.index)['total_spend_cpm'].sum().plot(kind='line', ax=ax1, figsize=(20,5), legend = True)

# %%
campnew.columns
# Out:
# Index(['Unnamed: 0', 'business_vertical_x', 'country_x', 'region', 'city_code',
#        'strategy_id', 'channel_name_x', 'goal_type', 'total_spend_cpm',
#        'impressions', 'clicks', 'conversions', 'business_vertical_y',
#        'channel_name_y', 'country_y'],
#       dtype='object')

# %%
fig = plt.figure()
plt.subplots_adjust(hspace=0.2)

ax1 = fig.add_subplot(311)
ax2 = fig.add_subplot(312)
ax3 = fig.add_subplot(313)

campnew.groupby([campnew.index,'channel_name_y'])['impressions'].sum().unstack().plot(kind='line', ax=ax1, figsize=(20,14), legend = True)
campnew.groupby([campnew.index,'channel_name_y'])['clicks'].sum().unstack().plot(kind='line', ax=ax2, figsize=(20,14), legend = True)
campnew.groupby([campnew.index,'channel_name_y'])['conversions'].sum().unstack().plot(kind='line',ax=ax3, figsize=(20,14), legend = True)
#campnew.groupby([campnew.index,'channel_name_y'])['total_spend_cpm'].sum().unstack().plot(kind='line', ax=ax1, figsize=(20,5), legend = True)

# %% [markdown]
# #### <font color=red>Observation: </font>
# #### As the value of conversions is always 0, there is no meaning to use a model to predict. Simply guess the future conversions is also 0.
# #### From 17Sep2018 to 26Sep2018, impressions and clicks use display and mobile channels. While from 26Sep2018 to 04Oct2018, the channel becomes unknown (data missing). Therefore, we will analyze based on the data from 17Sep2018 to 25Sep2018.

# %% [markdown]
# ### Decompose Impressions

# %%
#select dataframe with mobile channel and timeseries before 26Sep2018
campnew=campnew[(campnew['channel_name_y']=='Mobile') & (campnew.index <='2018-09-25')]

# %%
#decompose time series into three distinct components: trend, seasonality, and noise
import statsmodels.api as sm
from pylab import rcParams
rcParams['figure.figsize'] = 18, 8
decomposition = sm.tsa.seasonal_decompose(campnew.groupby(campnew.index)['impressions'].sum(), model='additive')
fig = decomposition.plot()
plt.show()

# %% [markdown]
# #### <font color=red>Observation: </font>
# ####   From the decomposed charts, impressions' trend is decreaing among 20-22Sep2018, and have NO seasonality behavior.

# %% [markdown]
# ### ARIMA

# %% [markdown]
# #### From previous observation, we first differentiate the time series of impressions to make it more stationary, this helps determine the **d value** in ARIMA(p,d,q) model

# %%
#select impressions data series
series = campnew['impressions']
series.head()
# Out:
# date
# 2018-09-17      1.0
# 2018-09-17     24.0
# 2018-09-17    129.0
# 2018-09-17    217.0
# 2018-09-17    201.0
# Name: impressions, dtype: float64

# %%
#try differentiating using 1 and 2
def parser(x):
	return dt.datetime.strptime(x, '%d/%m/%Y')
fig = plt.figure(figsize=(20,5))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
diff1 = series.diff(1)
diff1.plot(ax=ax1)
diff2 = series.diff(2)
diff2.plot(ax=ax2)

# %% [markdown]
# #### <font color=red>Observation: </font>
# #### We will use 1 as value of d in model ARIMA(p,d,q) since 1 and 2 doesn't show much difference from the chart

# %% [markdown]
# ### We need to determine p and q value, which will determine model selection
# #### First, check the ACF and PACF with lags 100 and 20

# %%
#autocorrelation
from pandas.plotting import autocorrelation_plot
autocorrelation_plot(series)
plt.show()

# %%
#acf & pacf
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

fig = plt.figure(figsize=(20,5))
plt.subplots_adjust(hspace=0.4)
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)
plot_acf(series,lags=100,ax=ax1)
plot_pacf(series, lags=100, ax=ax2)
plot_acf(series,lags=20,ax=ax3)
plot_pacf(series, lags=20, ax=ax4)

# %% [markdown]
# #### <font color=red>Observation: </font>
# #### From ACF, the autocorrelations are significant for lag 6. After lag 6, the autocorrelation becomes 0. ---> MA(q)
# #### From PACF, the partial autocorrelation is significant at lag 2. ---> AR(p)
# #### Therefore, we will testing by using AR variable p=4, MA variable q=6.

# %%
from statsmodels.tsa.arima_model import ARIMA
# fit model
model = ARIMA(series, order=(4,1,6))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# plot residual errors
residuals = pd.DataFrame(model_fit.resid)
print("The residual errors show that there may still be some trend information not captured by the model:")
residuals.plot()
plt.show()
print("The density plot of the residual error values:")
residuals.plot(kind='kde')
plt.show()
print("Below shows the distribution of the residual errors. The mean value shows there is a bias in the prediction:")
print(residuals.describe())
# Out:
# c:\users\chloe\appdata\local\programs\python\python37-32\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# c:\users\chloe\appdata\local\programs\python\python37-32\lib\site-packages\statsmodels\tsa\base\tsa_model.py:219: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:          D.impressions   No. Observations:                17089
# Model:                 ARIMA(4, 1, 6)   Log Likelihood             -165651.777
# Method:                       css-mle   S.D. of innovations           3921.960
# Date:                Mon, 16 Sep 2019   AIC                         331327.554
# Time:                        08:27:38   BIC                         331420.508
# Sample:                             1   HQIC                        331358.199
#
# =======================================================================================
#                           coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------------
# const                  -0.0727      0.025     -2.866      0.004      -0.122      -0.023
# ar.L1.D.impressions     1.2585      0.010    132.239      0.000       1.240       1.277
# ar.L2.D.impressions    -0.9049      0.015    -62.219      0.000      -0.933      -0.876
# ar.L3.D.impressions     0.4994      0.017     28.707      0.000       0.465       0.533
# ar.L4.D.impressions    -0.1565      0.014    -11.568      0.000      -0.183      -0.130
# ma.L1.D.impressions    -1.6064      0.006   -283.565      0.000      -1.618      -1.595
# ma.L2.D.impressions     1.1475      0.009    128.041      0.000       1.130       1.165
# ma.L3.D.impressions    -0.6902      0.012    -58.762      0.000      -0.713      -0.667
# ma.L4.D.impressions     0.1690      0.015     11.639      0.000       0.141       0.198
# ma.L5.D.impressions     0.1030      0.014      7.503      0.000       0.076       0.130
# ma.L6.D.impressions    -0.1228      0.011    -11.465      0.000      -0.144      -0.102
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.1233           -1.5823j            1.5871           -0.2376
# AR.2            0.1233           +1.5823j            1.5871            0.2376
# AR.3            1.4719           -0.6083j            1.5926           -0.0624
# AR.4            1.4719           +0.6083j            1.5926            0.0624
# MA.1           -0.0466           -1.3350j            1.3358           -0.2555
# MA.2           -0.0466           +1.3350j            1.3358            0.2555
# MA.3           -2.2734           -0.0000j            2.2734           -0.5000
# MA.4            1.0002           -0.0000j            1.0002           -0.0000
# MA.5            1.1025           -0.8897j            1.4167           -0.1081
# MA.6            1.1025           +0.8897j            1.4167            0.1081
# -----------------------------------------------------------------------------
# The residual errors show that there may still be some trend information not captured by the model:
# The density plot of the residual error values:
# Below shows the distribution of the residual errors. The mean value shows there is a bias in the prediction:
#                    0
# count   17089.000000
# mean        0.100170
# std      3923.612023
# min   -142379.814377
# 25%      -249.823380
# 50%      -150.832552
# 75%       -22.046021
# max    138598.393657

# %% [markdown]
# #### <font color=red>Observation: </font>
# #### The residual errors seem fine with zero mean and uniform variance

# %%
#test error of the model
from sklearn.metrics import mean_squared_error
X = series.values
size = int(len(X) * 0.66)
train, test = X[0:size],  X[size:len(X)]
history = [x for x in train]
predictions = list()
for t in range(len(test)):
	model = ARIMA(history, order=(4,1,0))
	model_fit = model.fit(disp=0)
	output = model_fit.forecast()
	yhat = output[0]
	predictions.append(yhat)
	obs = test[t]
	history.append(obs)
	print('predicted=%f, expected=%f' % (yhat, obs))
error = mean_squared_error(test, predictions)
print('Test MSE: %.3f' % error)
# Out:
# predicted=3.485006, expected=10.000000
# predicted=7.838672, expected=2.000000
# predicted=2.586677, expected=2.000000
# predicted=2.230589, expected=912.000000
# predicted=691.983513, expected=1.000000
# predicted=56.047420, expected=2.000000
# predicted=47.971661, expected=6.000000
# predicted=-7.640661, expected=11.000000
# predicted=142.368136, expected=0.000000
# predicted=1.070395, expected=8.000000
# predicted=6.830171, expected=3.000000
# predicted=3.471714, expected=26.000000
# predicted=21.901163, expected=4.000000
# predicted=4.605111, expected=0.000000
# predicted=2.680972, expected=5.000000
# predicted=4.071097, expected=16.000000
# predicted=16.175869, expected=4.000000
# predicted=4.813769, expected=36.000000
# predicted=28.264351, expected=3.000000
# predicted=5.108468, expected=3.000000
# predicted=6.559884, expected=3.000000
# predicted=2.689060, expected=27.000000
# predicted=26.026639, expected=2.000000
# predicted=3.656786, expected=10.000000
# predicted=9.461500, expected=6.000000
# predicted=5.303468, expected=1.000000
# predicted=5.544525, expected=0.000000
# predicted=0.516538, expected=8.000000
# predicted=7.496175, expected=1.000000
# predicted=2.094379, expected=11.000000
# predicted=8.948163, expected=12.000000
# predicted=9.684037, expected=4.000000
# predicted=5.453555, expected=19.000000
# predicted=15.238914, expected=19.000000
# predicted=17.169232, expected=1.000000
# predicted=4.541023, expected=4.000000
# predicted=4.374320, expected=1.000000
# predicted=3.563777, expected=3.000000
# predicted=5.304424, expected=15.000000
# predicted=11.688570, expected=87.000000
# predicted=67.555555, expected=62.000000
# predicted=52.988359, expected=1.000000
# predicted=9.044104, expected=0.000000
# predicted=4.185372, expected=9.000000
# predicted=18.756379, expected=4.000000
# predicted=12.630242, expected=1.000000
# predicted=1.595348, expected=47.000000
# predicted=35.763261, expected=18.000000
# predicted=17.727705, expected=63.000000
# predicted=51.765497, expected=29.000000
# predicted=26.100572, expected=22.000000
# predicted=28.207078, expected=14.000000
# predicted=15.138453, expected=8.000000
# predicted=16.827951, expected=0.000000
# predicted=5.122272, expected=1.000000
# predicted=4.190897, expected=9.000000
# predicted=8.820723, expected=1.000000
# predicted=2.510727, expected=3.000000
# predicted=2.774227, expected=4.000000
# predicted=3.280973, expected=6.000000
# predicted=6.239921, expected=1.000000
# predicted=1.418693, expected=2.000000
# predicted=2.262282, expected=5.000000
# predicted=4.461106, expected=16.000000
# predicted=13.389047, expected=10.000000
# predicted=8.894708, expected=3.000000
# predicted=3.896215, expected=2.000000
# predicted=2.708999, expected=4.000000
# predicted=5.506527, expected=2.000000
# predicted=3.275989, expected=7.000000
# predicted=6.037899, expected=4.000000
# predicted=3.783138, expected=0.000000
# predicted=1.147857, expected=4.000000
# predicted=3.430129, expected=7.000000
# predicted=6.511621, expected=6.000000
# predicted=5.748786, expected=4.000000
# predicted=3.684157, expected=0.000000
# predicted=1.027921, expected=0.000000
# predicted=1.144315, expected=2.000000
# predicted=2.339288, expected=10.000000
# predicted=8.283849, expected=1.000000
# predicted=1.448410, expected=11.000000
# predicted=8.875097, expected=11.000000
# predicted=9.191226, expected=29.000000
# predicted=24.638103, expected=6.000000
# predicted=6.807479, expected=5.000000
# predicted=7.069174, expected=0.000000
# predicted=1.807061, expected=12.000000
# predicted=13.513700, expected=11.000000
# predicted=9.854851, expected=2.000000
# predicted=3.503596, expected=2.000000
# predicted=2.023726, expected=21.000000
# predicted=17.742500, expected=0.000000
# predicted=2.922239, expected=2.000000
# predicted=2.843349, expected=14.000000
# predicted=10.731685, expected=51.000000
# predicted=42.661267, expected=10.000000
# predicted=11.266284, expected=3.000000
# predicted=5.541773, expected=13.000000
# predicted=11.880062, expected=2.000000
# predicted=9.765588, expected=19.000000
# predicted=16.600878, expected=8.000000
# predicted=7.544116, expected=1.000000
# predicted=4.066934, expected=4.000000
# predicted=3.524951, expected=1.000000
# predicted=3.716353, expected=14.000000
# predicted=12.031371, expected=0.000000
# predicted=0.966563, expected=11.000000
# predicted=9.618282, expected=25.000000
# predicted=19.550957, expected=9.000000
# predicted=10.902601, expected=36.000000
# predicted=28.931001, expected=16.000000
# predicted=15.969679, expected=1.000000
# predicted=7.059009, expected=2.000000
# predicted=3.203128, expected=4.000000
# predicted=8.251729, expected=2.000000
# predicted=4.182608, expected=1.000000
# predicted=1.196815, expected=1.000000
# predicted=1.155453, expected=1.000000
# predicted=1.425569, expected=3.000000
# predicted=2.662520, expected=46.000000
# predicted=35.228780, expected=3.000000
# predicted=5.269393, expected=2.000000
# predicted=4.124387, expected=24.000000
# predicted=18.263331, expected=0.000000
# predicted=8.211986, expected=34.000000
# predicted=27.398211, expected=1.000000
# predicted=2.721818, expected=66.000000
# predicted=55.323433, expected=3.000000
# predicted=5.742790, expected=0.000000
# predicted=8.481584, expected=5.000000
# predicted=3.172730, expected=7.000000
# predicted=15.226723, expected=1.000000
# predicted=1.862784, expected=1.000000
# predicted=1.101535, expected=28.000000
# predicted=21.969223, expected=1.000000
# predicted=3.470187, expected=7.000000
# predicted=6.913850, expected=1.000000
# predicted=0.979119, expected=0.000000
# predicted=4.500445, expected=16.000000
# predicted=12.228128, expected=74.000000
# predicted=58.047788, expected=1.000000
# predicted=6.075050, expected=6.000000
# predicted=8.128119, expected=101.000000
# predicted=78.281289, expected=16.000000
# predicted=29.209974, expected=8.000000
# predicted=12.179119, expected=16.000000
# predicted=12.886960, expected=30.000000
# predicted=38.660617, expected=8.000000
# predicted=10.874172, expected=6.000000
# predicted=7.486860, expected=7.000000
# predicted=7.991829, expected=1.000000
# predicted=5.757356, expected=1.000000
# predicted=2.259501, expected=13.000000
# predicted=10.745409, expected=0.000000
# predicted=1.828111, expected=14.000000
# predicted=11.402308, expected=16.000000
# predicted=12.919449, expected=32.000000
# predicted=27.811861, expected=24.000000
# predicted=20.693453, expected=0.000000
# predicted=4.861787, expected=5.000000
# predicted=6.903752, expected=90.000000
# predicted=72.870752, expected=21.000000
# predicted=24.991077, expected=71.000000
# predicted=59.539982, expected=12.000000
# predicted=13.826911, expected=3.000000
# predicted=19.464450, expected=1.000000
# predicted=3.632953, expected=12.000000
# predicted=19.540397, expected=2.000000
# predicted=3.989876, expected=3.000000
# predicted=3.424346, expected=118.000000
# predicted=89.704115, expected=1.000000
# predicted=9.594272, expected=0.000000
# predicted=6.278878, expected=1.000000
# predicted=-0.388860, expected=6.000000
# predicted=21.877651, expected=40.000000
# predicted=30.871292, expected=4.000000
# predicted=5.679056, expected=0.000000
# predicted=2.322171, expected=8.000000
# predicted=6.590390, expected=0.000000
# predicted=6.275059, expected=3.000000
# predicted=3.264490, expected=6.000000
# predicted=4.613813, expected=11.000000
# predicted=10.015273, expected=2.000000
# predicted=2.426088, expected=3.000000
# predicted=3.304410, expected=2.000000
# predicted=2.520170, expected=5.000000
# predicted=5.643111, expected=13.000000
# predicted=10.501300, expected=4.000000
# predicted=4.462730, expected=4.000000
# predicted=4.148856, expected=1.000000
# predicted=1.748029, expected=34.000000
# predicted=27.882523, expected=1.000000
# predicted=3.342756, expected=1.000000
# predicted=3.108678, expected=3.000000
# predicted=2.058302, expected=24.000000
# predicted=23.386145, expected=1.000000
# predicted=2.456730, expected=6.000000
# predicted=5.925755, expected=5.000000
# predicted=4.300705, expected=3.000000
# predicted=6.373735, expected=0.000000
# predicted=0.492834, expected=5.000000
# predicted=4.751221, expected=0.000000
# predicted=0.985328, expected=52.000000
# predicted=40.109164, expected=2.000000
# predicted=4.511288, expected=0.000000
# predicted=3.480415, expected=1.000000
# predicted=0.137766, expected=6.000000
# predicted=12.196126, expected=14.000000
# predicted=11.309280, expected=15.000000
# predicted=12.484884, expected=27.000000
# predicted=22.121834, expected=8.000000
# predicted=9.098749, expected=23.000000
# predicted=21.114174, expected=11.000000
# predicted=11.920979, expected=8.000000
# predicted=11.719708, expected=18.000000
# predicted=15.524916, expected=10.000000
# predicted=12.262043, expected=1.000000
# predicted=3.758048, expected=4.000000
# predicted=4.518858, expected=12.000000
# predicted=11.880344, expected=8.000000
# predicted=8.424510, expected=34.000000
# predicted=26.941971, expected=11.000000
# predicted=11.166066, expected=41.000000
# predicted=35.093527, expected=2.000000
# predicted=5.188959, expected=25.000000
# predicted=25.969821, expected=3.000000
# predicted=4.891098, expected=0.000000
# predicted=7.419166, expected=1.000000
# predicted=0.855812, expected=1.000000
# predicted=4.437196, expected=3.000000
# predicted=2.822866, expected=40.000000
# predicted=30.534110, expected=9.000000
# predicted=9.463882, expected=0.000000
# predicted=2.658464, expected=1.000000
# predicted=1.097707, expected=0.000000
# predicted=2.571236, expected=1.000000
# predicted=0.930651, expected=6.000000
# predicted=5.522453, expected=11.000000
# predicted=8.874801, expected=9.000000
# predicted=7.906402, expected=550.000000
# predicted=418.055625, expected=27.000000
# predicted=54.065505, expected=2.000000
# predicted=32.414334, expected=46.000000
# predicted=30.041934, expected=17.000000
# predicted=95.888494, expected=7.000000
# predicted=12.561975, expected=23.000000
# predicted=18.361548, expected=12.000000
# predicted=17.308016, expected=5.000000
# predicted=8.053687, expected=0.000000
# predicted=1.607924, expected=23.000000
# predicted=20.889605, expected=40.000000
# predicted=33.364280, expected=19.000000
# predicted=18.655484, expected=1.000000
# predicted=3.582067, expected=0.000000
# predicted=3.834149, expected=1.000000
# predicted=6.404165, expected=5.000000
# predicted=6.618108, expected=4.000000
# predicted=3.523663, expected=1.000000
# predicted=1.232675, expected=0.000000
# predicted=0.338259, expected=0.000000
# predicted=0.727363, expected=2.000000
# predicted=2.087926, expected=2.000000
# predicted=1.780237, expected=67.000000
# predicted=51.005514, expected=7.000000
# predicted=9.328427, expected=10.000000
# predicted=11.646795, expected=9.000000
# predicted=7.129137, expected=7.000000
# predicted=16.059341, expected=6.000000
# predicted=6.302415, expected=3.000000
# predicted=4.321593, expected=0.000000
# predicted=1.701417, expected=3.000000
# predicted=3.367778, expected=79.000000
# predicted=60.896667, expected=44.000000
# predicted=38.599781, expected=0.000000
# predicted=6.547705, expected=2.000000
# predicted=3.085304, expected=9.000000
# predicted=17.901561, expected=2.000000
# predicted=8.592668, expected=1.000000
# predicted=1.303253, expected=2.000000
# predicted=1.844111, expected=13.000000
# predicted=11.313021, expected=8.000000
# predicted=7.210421, expected=1.000000
# predicted=2.005710, expected=1.000000
# predicted=1.334131, expected=24.000000
# predicted=20.094890, expected=1.000000
# predicted=3.381008, expected=20.000000
# predicted=16.565564, expected=1.000000
# predicted=1.800870, expected=27.000000
# predicted=25.038358, expected=8.000000
# predicted=7.575007, expected=3.000000
# predicted=7.026906, expected=2.000000
# predicted=1.869367, expected=44.000000
# predicted=37.465896, expected=3.000000
# predicted=6.098685, expected=12.000000
# predicted=11.910140, expected=0.000000
# predicted=0.541606, expected=2.000000
# predicted=8.526423, expected=1.000000
# predicted=1.148759, expected=18.000000
# predicted=15.561886, expected=26.000000
# predicted=20.791870, expected=3.000000
# predicted=4.995931, expected=1.000000
# predicted=2.146671, expected=1.000000
# predicted=3.244608, expected=14.000000
# predicted=14.488392, expected=4.000000
# predicted=4.333219, expected=7.000000
# predicted=6.382452, expected=1.000000
# predicted=1.325092, expected=12.000000
# predicted=11.504240, expected=5.000000
# predicted=5.036611, expected=1.000000
# predicted=2.671064, expected=65.000000
# predicted=49.562333, expected=3.000000
# predicted=7.844059, expected=1.000000
# predicted=4.941121, expected=3.000000
# predicted=1.729571, expected=2.000000
# predicted=11.222941, expected=14.000000
# predicted=11.307176, expected=56.000000
# predicted=43.479537, expected=1.000000
# predicted=5.178416, expected=4.000000
# predicted=6.022258, expected=2.000000
# predicted=3.076239, expected=0.000000
# predicted=8.509161, expected=19.000000
# predicted=14.594177, expected=2.000000
# predicted=3.193944, expected=18.000000
# predicted=15.015922, expected=21.000000
# predicted=16.816616, expected=3.000000
# predicted=7.177538, expected=2.000000
# predicted=2.798251, expected=7.000000
# predicted=7.920946, expected=22.000000
# predicted=20.224285, expected=1.000000
# predicted=2.820358, expected=0.000000
# predicted=1.367500, expected=9.000000
# predicted=7.592750, expected=11.000000
# predicted=12.077126, expected=8.000000
# predicted=7.314005, expected=17.000000
# predicted=13.789108, expected=3.000000
# predicted=4.846304, expected=1.000000
# predicted=3.294935, expected=2.000000
# predicted=2.662631, expected=33.000000
# predicted=27.631150, expected=5.000000
# predicted=6.261678, expected=14.000000
# predicted=12.694657, expected=5.000000
# predicted=4.703252, expected=2.000000
# predicted=7.283264, expected=27.000000
# predicted=21.375091, expected=7.000000
# predicted=8.979869, expected=3.000000
# predicted=4.756873, expected=14.000000
# predicted=11.061362, expected=9.000000
# predicted=11.656754, expected=2.000000
# predicted=3.738261, expected=1.000000
# predicted=1.576264, expected=1.000000
# predicted=2.843880, expected=8.000000
# predicted=7.464035, expected=79.000000
# predicted=60.683700, expected=9.000000
# predicted=12.015545, expected=1.000000
# predicted=5.319920, expected=9.000000
# predicted=7.412283, expected=15.000000
# predicted=23.398210, expected=0.000000
# predicted=2.643679, expected=0.000000
# predicted=0.780259, expected=82.000000
# predicted=63.266775, expected=17.000000
# predicted=19.916361, expected=1.000000
# predicted=5.907666, expected=10.000000
# predicted=7.361470, expected=12.000000
# predicted=21.511612, expected=10.000000
# predicted=11.269365, expected=2.000000
# predicted=2.720066, expected=1.000000
# predicted=2.679955, expected=3.000000
# predicted=4.053069, expected=2.000000
# predicted=3.180352, expected=24.000000
# predicted=18.740761, expected=20.000000
# predicted=16.780629, expected=0.000000
# predicted=2.804375, expected=26.000000
# predicted=20.679807, expected=5.000000
# predicted=8.560519, expected=2.000000
# predicted=6.055369, expected=16.000000
# predicted=12.138164, expected=5.000000
# predicted=8.573282, expected=2.000000
# predicted=3.324573, expected=23.000000
# predicted=17.875860, expected=19.000000
# predicted=18.133158, expected=1.000000
# predicted=3.745825, expected=7.000000
# predicted=6.299890, expected=7.000000
# predicted=8.874620, expected=0.000000
# predicted=3.535794, expected=52.000000
# predicted=39.819702, expected=4.000000
# predicted=7.025085, expected=585.000000
# predicted=447.325561, expected=1.000000
# predicted=34.720009, expected=1.000000
# predicted=37.969433, expected=2.000000
# predicted=-5.902146, expected=1.000000
# predicted=86.604078, expected=4.000000
# predicted=3.324602, expected=2.000000
# predicted=1.920961, expected=2.000000
# predicted=2.115178, expected=10.000000
# predicted=7.889972, expected=2.000000
# predicted=2.764638, expected=15.000000
# predicted=12.258886, expected=4.000000
# predicted=4.171445, expected=2.000000
# predicted=3.947456, expected=6.000000
# predicted=4.953029, expected=5.000000
# predicted=6.386445, expected=14.000000
# predicted=11.768335, expected=9.000000
# predicted=8.109759, expected=3.000000
# predicted=4.322053, expected=1.000000
# predicted=1.928171, expected=4.000000
# predicted=5.168493, expected=8.000000
# predicted=7.626980, expected=10.000000
# predicted=8.679358, expected=1.000000
# predicted=6.562828, expected=1.000000
# predicted=1.485269, expected=5.000000
# predicted=7.982493, expected=2.000000
# predicted=3.096286, expected=4.000000
# predicted=4.267687, expected=1.000000
# predicted=1.171938, expected=8.000000
# predicted=7.029811, expected=14.000000
# predicted=11.371479, expected=17.000000
# predicted=14.687792, expected=0.000000
# predicted=1.745583, expected=2.000000
# predicted=3.353461, expected=22.000000
# predicted=18.608737, expected=5.000000
# predicted=7.677970, expected=4.000000
# predicted=4.411660, expected=7.000000
# predicted=5.782401, expected=2.000000
# predicted=5.284056, expected=8.000000
# predicted=7.212760, expected=8.000000
# predicted=7.125417, expected=1.000000
# predicted=2.631708, expected=13.000000
# predicted=10.499480, expected=2.000000
# predicted=3.393611, expected=4.000000
# predicted=4.965308, expected=27.000000
# predicted=20.768991, expected=1.000000
# predicted=4.428191, expected=3.000000
# predicted=3.936031, expected=4.000000
# predicted=3.470747, expected=16.000000
# predicted=16.456532, expected=22.000000
# predicted=17.926155, expected=19.000000
# predicted=16.891908, expected=4.000000
# predicted=5.628629, expected=0.000000
# predicted=3.235304, expected=15.000000
# predicted=14.531289, expected=29.000000
# predicted=25.593698, expected=1.000000
# predicted=3.811883, expected=1.000000
# predicted=2.075675, expected=12.000000
# predicted=11.000423, expected=71.000000
# predicted=58.809872, expected=0.000000
# predicted=4.924412, expected=1.000000
# predicted=4.329291, expected=21.000000
# predicted=16.749904, expected=16.000000
# predicted=23.816449, expected=7.000000
# predicted=7.297321, expected=3.000000
# predicted=3.351024, expected=4.000000
# predicted=6.417001, expected=20.000000
# predicted=17.794016, expected=0.000000
# predicted=2.364817, expected=27.000000
# predicted=21.861468, expected=8.000000
# predicted=7.963890, expected=3.000000
# predicted=7.040782, expected=89.000000
# predicted=67.668876, expected=2.000000
# predicted=10.757667, expected=0.000000
# predicted=5.749855, expected=34.000000
# predicted=25.078109, expected=2.000000
# predicted=16.529111, expected=1.000000
# predicted=2.888532, expected=14.000000
# predicted=10.300419, expected=0.000000
# predicted=5.828316, expected=0.000000
# predicted=0.987116, expected=16.000000
# predicted=12.080171, expected=5.000000
# predicted=6.783703, expected=4.000000
# predicted=4.135903, expected=0.000000
# predicted=0.266644, expected=2.000000
# predicted=3.992567, expected=78.000000
# predicted=59.918646, expected=1.000000
# predicted=6.042524, expected=17.000000
# predicted=16.862516, expected=31.000000
# predicted=23.761637, expected=16.000000
# predicted=26.226760, expected=51.000000
# predicted=41.079700, expected=4.000000
# predicted=8.907555, expected=0.000000
# predicted=7.134424, expected=48.000000
# predicted=38.222590, expected=0.000000
# predicted=10.244239, expected=24.000000
# predicted=21.205748, expected=21.000000
# predicted=16.666763, expected=0.000000
# predicted=9.482814, expected=2.000000
# predicted=2.245244, expected=420.000000
# predicted=321.701650, expected=4.000000
# predicted=30.965405, expected=9.000000
# predicted=28.274676, expected=0.000000
# predicted=-4.799413, expected=4.000000
# predicted=64.954363, expected=5.000000
# predicted=4.486739, expected=3.000000
# predicted=4.089246, expected=2.000000
# predicted=1.890127, expected=28.000000
# predicted=22.010053, expected=0.000000
# predicted=2.442241, expected=8.000000
# predicted=7.891884, expected=1.000000
# predicted=1.134046, expected=0.000000
# predicted=4.564961, expected=4.000000
# predicted=2.971495, expected=17.000000
# predicted=14.279598, expected=35.000000
# predicted=27.880660, expected=5.000000
# predicted=6.657308, expected=1.000000
# predicted=3.173140, expected=0.000000
# predicted=2.316520, expected=2.000000
# predicted=6.623974, expected=1.000000
# predicted=1.594289, expected=5.000000
# predicted=4.096447, expected=0.000000
# predicted=0.317424, expected=1.000000
# predicted=1.289870, expected=2.000000
# predicted=1.651940, expected=0.000000
# predicted=0.900744, expected=6.000000
# predicted=4.635151, expected=0.000000
# predicted=0.472264, expected=0.000000
# predicted=0.596322, expected=3.000000
# predicted=2.190641, expected=1.000000
# predicted=1.813585, expected=1.000000
# predicted=0.968552, expected=0.000000
# predicted=0.067782, expected=1.000000
# predicted=1.234021, expected=4.000000
# predicted=3.223415, expected=4.000000
# predicted=3.464694, expected=4.000000
# predicted=3.456093, expected=3.000000
# predicted=2.802969, expected=1.000000
# predicted=1.667477, expected=1.000000
# predicted=1.499004, expected=0.000000
# predicted=0.653713, expected=2.000000
# predicted=1.992020, expected=1.000000
# predicted=1.008360, expected=0.000000
# predicted=0.306452, expected=2.000000
# predicted=1.538706, expected=1.000000
# predicted=1.154843, expected=2.000000
# predicted=1.822450, expected=2.000000
# predicted=1.656592, expected=5.000000
# predicted=4.288003, expected=5.000000
# predicted=4.304482, expected=1.000000
# predicted=1.570716, expected=1.000000
# predicted=1.293337, expected=3.000000
# predicted=3.046452, expected=5.000000
# predicted=4.735810, expected=2.000000
# predicted=2.094939, expected=3.000000
# predicted=2.749534, expected=3.000000
# predicted=2.921956, expected=6.000000
# predicted=5.581106, expected=1.000000
# predicted=1.514629, expected=1.000000
# predicted=1.518139, expected=1.000000
# predicted=1.223620, expected=2.000000
# predicted=2.490411, expected=15.000000
# predicted=11.670912, expected=0.000000
# predicted=1.117789, expected=6.000000
# predicted=5.425331, expected=1.000000
# predicted=1.196446, expected=1.000000
# predicted=3.317543, expected=6.000000
# predicted=4.574163, expected=1.000000
# predicted=2.027132, expected=4.000000
# predicted=3.526904, expected=1.000000
# predicted=1.107485, expected=1.000000
# predicted=1.884162, expected=0.000000
# predicted=0.200396, expected=1.000000
# predicted=1.380504, expected=0.000000
# predicted=0.191420, expected=1.000000
# predicted=0.954926, expected=4.000000
# predicted=3.076928, expected=1.000000
# predicted=1.190701, expected=2.000000
# predicted=1.763265, expected=5.000000
# predicted=4.049330, expected=5.000000
# predicted=4.757796, expected=75.000000
# predicted=57.516098, expected=1.000000
# predicted=5.655161, expected=0.000000
# predicted=4.515596, expected=3.000000
# predicted=2.016694, expected=1.000000
# predicted=11.907026, expected=2.000000
# predicted=1.873033, expected=0.000000
# predicted=0.126725, expected=1.000000
# predicted=1.284605, expected=3.000000
# predicted=2.451545, expected=1.000000
# predicted=1.278238, expected=47.000000
# predicted=35.822589, expected=1.000000
# predicted=3.683664, expected=4.000000
# predicted=5.893758, expected=5.000000
# predicted=3.570838, expected=0.000000
# predicted=7.367735, expected=1.000000
# predicted=1.101781, expected=28.000000
# predicted=21.799322, expected=1.000000
# predicted=3.191279, expected=0.000000
# predicted=1.461251, expected=29.000000
# predicted=21.790534, expected=1.000000
# predicted=6.554865, expected=0.000000
# predicted=1.672187, expected=0.000000
# predicted=-0.351760, expected=2.000000
# predicted=5.749986, expected=3.000000
# predicted=2.538224, expected=0.000000
# predicted=0.277857, expected=0.000000
# predicted=0.123874, expected=2.000000
# predicted=1.767216, expected=2.000000
# predicted=2.073192, expected=0.000000
# predicted=0.218915, expected=4.000000
# predicted=3.105280, expected=10.000000
# predicted=8.080837, expected=1.000000
# predicted=1.842591, expected=0.000000
# predicted=0.509159, expected=4.000000
# predicted=3.529677, expected=0.000000
# predicted=1.686595, expected=4.000000
# predicted=3.380667, expected=1.000000
# predicted=0.938159, expected=2.000000
# predicted=2.363063, expected=0.000000
# predicted=0.112854, expected=4.000000
# predicted=3.705080, expected=1.000000
# predicted=1.112378, expected=2.000000
# predicted=2.070097, expected=1.000000
# predicted=0.870854, expected=24.000000
# predicted=18.923958, expected=1.000000
# predicted=2.341823, expected=1.000000
# predicted=2.309897, expected=1.000000
# predicted=0.680999, expected=1.000000
# predicted=4.369108, expected=1.000000
# predicted=1.000000, expected=0.000000
# predicted=0.242001, expected=7.000000
# predicted=5.489042, expected=2.000000
# predicted=2.061074, expected=1.000000
# predicted=1.376306, expected=3.000000
# predicted=2.336880, expected=1.000000
# predicted=1.982917, expected=0.000000
# predicted=0.489652, expected=2.000000
# predicted=1.671315, expected=0.000000
# predicted=0.543330, expected=1.000000
# predicted=1.005510, expected=1.000000
# predicted=0.789067, expected=1.000000
# predicted=1.160350, expected=1.000000
# predicted=0.853517, expected=1.000000
# predicted=1.000000, expected=1.000000
# predicted=0.999999, expected=3.000000
# predicted=2.515994, expected=3.000000
# predicted=2.633881, expected=6.000000
# predicted=5.009038, expected=1.000000
# predicted=1.368144, expected=0.000000
# predicted=0.760144, expected=1.000000
# predicted=1.164678, expected=1.000000
# predicted=1.681834, expected=0.000000
# predicted=0.255873, expected=4.000000
# predicted=3.068563, expected=6.000000
# predicted=4.916231, expected=6.000000
# predicted=5.250319, expected=1.000000
# predicted=1.359543, expected=1.000000
# predicted=1.623018, expected=3.000000
# predicted=3.179063, expected=2.000000
# predicted=2.608299, expected=1.000000
# predicted=1.160110, expected=2.000000
# predicted=1.780844, expected=1.000000
# predicted=1.338040, expected=1.000000
# predicted=1.197064, expected=0.000000
# predicted=0.228132, expected=1.000000
# predicted=1.087539, expected=1.000000
# predicted=0.949417, expected=2.000000
# predicted=1.771866, expected=4.000000
# predicted=3.186450, expected=0.000000
# predicted=0.469416, expected=18.000000
# predicted=13.964871, expected=1.000000
# predicted=2.056329, expected=4.000000
# predicted=4.587213, expected=0.000000
# predicted=0.036576, expected=0.000000
# predicted=2.825019, expected=0.000000
# predicted=0.090868, expected=81.000000
# predicted=61.983541, expected=1.000000
# predicted=5.532272, expected=4.000000
# predicted=7.188007, expected=1.000000
# predicted=-0.079169, expected=1.000000
# predicted=12.870411, expected=14.000000
# predicted=10.812347, expected=0.000000
# predicted=0.261420, expected=1.000000
# predicted=1.155099, expected=1.000000
# predicted=1.253386, expected=0.000000
# predicted=0.111736, expected=1.000000
# predicted=0.793214, expected=1.000000
# predicted=0.948991, expected=1.000000
# predicted=1.012486, expected=14.000000
# predicted=10.666357, expected=4.000000
# predicted=4.055192, expected=3.000000
# predicted=3.355186, expected=34.000000
# predicted=26.020555, expected=7.000000
# predicted=9.498165, expected=1.000000
# predicted=3.461147, expected=33.000000
# predicted=25.339344, expected=1.000000
# predicted=7.688203, expected=129.000000
# predicted=100.121416, expected=333.000000
# predicted=258.978261, expected=11.000000
# predicted=39.943674, expected=3.000000
# predicted=18.454591, expected=15.000000
# predicted=26.736066, expected=1.000000
# predicted=50.285647, expected=62.000000
# predicted=49.191043, expected=3.000000
# predicted=6.337455, expected=0.000000
# predicted=5.521716, expected=3.000000
# predicted=1.789179, expected=785.000000
# predicted=601.706408, expected=3.000000
# predicted=50.609211, expected=3.000000
# predicted=42.450880, expected=41.000000
# predicted=21.919721, expected=46.000000
# predicted=151.904079, expected=3.000000
# predicted=7.554323, expected=2.000000
# predicted=3.964375, expected=224.000000
# predicted=174.757752, expected=0.000000
# predicted=20.404872, expected=1.000000
# predicted=12.593424, expected=1.000000
# predicted=-1.688954, expected=4.000000
# predicted=35.824560, expected=1.000000
# predicted=1.036546, expected=1.000000
# predicted=1.153025, expected=1.000000
# predicted=0.962550, expected=162.000000
# predicted=122.959258, expected=1.000000
# predicted=10.794048, expected=1.000000
# predicted=9.212319, expected=7.000000
# predicted=3.518788, expected=636.000000
# predicted=504.155827, expected=2.000000
# predicted=40.690148, expected=0.000000
# predicted=32.621569, expected=4.000000
# predicted=-3.796419, expected=2.000000
# predicted=94.554045, expected=8.000000
# predicted=6.655824, expected=8.000000
# predicted=6.576970, expected=1.000000
# predicted=2.208269, expected=68.000000
# predicted=51.986568, expected=3.000000
# predicted=7.519709, expected=61.000000
# predicted=50.848299, expected=23.000000
# predicted=20.521059, expected=251.000000
# predicted=203.850273, expected=0.000000
# predicted=16.118673, expected=3.000000
# predicted=23.683358, expected=4.000000
# predicted=3.425373, expected=1.000000
# predicted=37.785384, expected=3.000000
# predicted=2.491686, expected=3.000000
# predicted=2.885706, expected=6.000000
# predicted=5.435493, expected=2.000000
# predicted=2.136011, expected=322.000000
# predicted=243.870256, expected=4.000000
# predicted=23.072503, expected=6.000000
# predicted=22.047181, expected=1.000000
# predicted=-2.403884, expected=0.000000
# predicted=47.313822, expected=9.000000
# predicted=7.352932, expected=2.000000
# predicted=2.920220, expected=5.000000
# predicted=4.500541, expected=2.000000
# predicted=1.803318, expected=20.000000
# predicted=16.761007, expected=0.000000
# predicted=1.548088, expected=1888.000000
# predicted=1426.767298, expected=2.000000
# predicted=116.419653, expected=1.000000
# predicted=100.100808, expected=0.000000
# predicted=-23.402148, expected=49.000000
# predicted=312.570647, expected=1.000000
# predicted=4.015293, expected=19.000000
# predicted=17.046901, expected=0.000000
# predicted=0.595390, expected=0.000000
# predicted=8.108190, expected=2.000000
# predicted=1.418297, expected=2.000000
# predicted=4.404220, expected=1.000000
# predicted=0.978377, expected=7.000000
# predicted=5.421262, expected=6.000000
# predicted=5.272422, expected=2.000000
# predicted=2.510980, expected=62.000000
# predicted=47.282615, expected=3.000000
# predicted=7.085150, expected=14.000000
# predicted=14.762588, expected=5.000000
# predicted=4.296750, expected=4.000000
# predicted=13.048924, expected=1.000000
# predicted=1.516224, expected=2.000000
# predicted=3.755259, expected=1.000000
# predicted=1.607207, expected=9.000000
# predicted=7.527109, expected=1.000000
# predicted=1.474244, expected=2.000000
# predicted=2.308796, expected=1.000000
# predicted=0.961008, expected=162.000000
# predicted=123.738326, expected=1.000000
# predicted=10.782878, expected=31.000000
# predicted=32.001674, expected=0.000000
# predicted=0.061246, expected=5.000000
# predicted=28.986715, expected=53.000000
# predicted=40.066555, expected=121.000000
# predicted=99.332432, expected=1.000000
# predicted=10.757398, expected=11.000000
# predicted=14.603638, expected=11.000000
# predicted=15.248181, expected=1241.000000
# predicted=955.560620, expected=2.000000
# predicted=77.586619, expected=29.000000
# predicted=86.778804, expected=1.000000
# predicted=-11.258805, expected=1.000000
# predicted=183.395755, expected=4.000000
# predicted=3.060924, expected=0.000000
# predicted=4.514375, expected=2.000000
# predicted=1.846955, expected=8575.000000
# predicted=6472.430610, expected=5504.000000
# predicted=4676.744465, expected=0.000000
# predicted=772.462471, expected=1.000000
# predicted=175.478120, expected=1.000000
# predicted=1184.014241, expected=22.000000
# predicted=820.081483, expected=1.000000
# predicted=2.129130, expected=0.000000
# predicted=1.318431, expected=1.000000
# predicted=0.677788, expected=0.000000
# predicted=3.258952, expected=2.000000
# predicted=1.706519, expected=8.000000
# predicted=6.147167, expected=0.000000
# predicted=0.733794, expected=10.000000
# predicted=7.931691, expected=1.000000
# predicted=1.554139, expected=4.000000
# predicted=4.758372, expected=1.000000
# predicted=0.924143, expected=5.000000
# predicted=5.485962, expected=0.000000
# predicted=0.450731, expected=1.000000
# predicted=1.581541, expected=1.000000
# predicted=0.899086, expected=0.000000
# predicted=0.841445, expected=1.000000
# predicted=0.793338, expected=0.000000
# predicted=0.194109, expected=1.000000
# predicted=0.951735, expected=0.000000
# predicted=0.048163, expected=1.000000
# predicted=0.951734, expected=1.000000
# predicted=0.802950, expected=1.000000
# predicted=1.012452, expected=3.000000
# predicted=2.363626, expected=6.000000
# predicted=4.895361, expected=1.000000
# predicted=1.405798, expected=1.000000
# predicted=1.230625, expected=16.000000
# predicted=12.551409, expected=22.000000
# predicted=18.490977, expected=0.000000
# predicted=2.286860, expected=94.000000
# predicted=72.020755, expected=104.000000
# predicted=86.266179, expected=619.000000
# predicted=481.541216, expected=592.000000
# predicted=488.561284, expected=2.000000
# predicted=81.512241, expected=1.000000
# predicted=38.601396, expected=2.000000
# predicted=84.640904, expected=5.000000
# predicted=90.320930, expected=0.000000
# predicted=0.685133, expected=5.000000
# predicted=4.150396, expected=18.000000
# predicted=14.119245, expected=47.000000
# predicted=37.552970, expected=1063.000000
# predicted=806.048267, expected=2012.000000
# predicted=1586.082959, expected=0.000000
# predicted=178.526317, expected=2.000000
# predicted=97.967283, expected=1.000000
# predicted=130.966304, expected=6.000000
# predicted=298.335594, expected=1.000000
# predicted=1.145170, expected=2.000000
# predicted=2.156280, expected=1.000000
# predicted=0.998459, expected=1.000000
# predicted=1.780834, expected=2.000000
# predicted=1.742334, expected=0.000000
# predicted=0.451874, expected=1.000000
# predicted=0.990397, expected=7.000000
# predicted=5.465147, expected=5.000000
# predicted=4.541806, expected=1.000000
# predicted=1.403564, expected=0.000000
# predicted=0.374951, expected=1.000000
# predicted=1.765153, expected=1.000000
# predicted=1.532668, expected=1.000000
# predicted=1.012450, expected=3.000000
# predicted=2.363624, expected=14.000000
# predicted=10.933620, expected=1.000000
# predicted=1.891478, expected=5.000000
# predicted=4.658666, expected=1.000000
# predicted=1.372883, expected=1.000000
# predicted=3.101717, expected=1.000000
# predicted=0.950200, expected=12.000000
# predicted=9.886408, expected=35.000000
# predicted=27.330517, expected=0.000000
# predicted=2.871640, expected=3.000000
# predicted=4.049638, expected=0.000000
# predicted=1.497618, expected=5.000000
# predicted=9.035220, expected=4.000000
# predicted=3.285249, expected=74.000000
# predicted=56.790157, expected=47.000000
# predicted=40.109672, expected=0.000000
# predicted=7.315422, expected=77.000000
# predicted=60.182940, expected=145.000000
# predicted=124.333226, expected=4.000000
# predicted=22.617176, expected=7.000000
# predicted=11.978496, expected=105.000000
# predicted=89.314092, expected=232.000000
# predicted=202.954658, expected=1.000000
# predicted=20.703146, expected=1.000000
# predicted=12.387295, expected=1.000000
# predicted=13.302267, expected=7.000000
# predicted=39.241902, expected=0.000000
# predicted=0.609488, expected=1.000000
# predicted=1.245947, expected=9.000000
# predicted=6.912463, expected=1.000000
# predicted=2.373813, expected=44.000000
# predicted=33.718651, expected=54.000000
# predicted=43.514602, expected=0.000000
# predicted=6.828254, expected=0.000000
# predicted=2.357991, expected=3.000000
# predicted=8.013498, expected=353.000000
# predicted=274.501948, expected=241.000000
# predicted=203.487633, expected=1.000000
# predicted=33.390807, expected=1.000000
# predicted=9.175941, expected=2.000000
# predicted=50.139261, expected=4.000000
# predicted=38.351746, expected=18.000000
# predicted=14.064575, expected=33.000000
# predicted=26.326073, expected=9.000000
# predicted=9.958523, expected=17.000000
# predicted=15.423945, expected=2.000000
# predicted=5.217718, expected=5.000000
# predicted=9.468242, expected=0.000000
# predicted=1.507529, expected=2.000000
# predicted=4.221175, expected=161.000000
# predicted=121.871266, expected=133.000000
# predicted=110.992749, expected=1.000000
# predicted=17.033202, expected=1.000000
# predicted=5.900449, expected=1.000000
# predicted=22.707765, expected=0.000000
# predicted=19.509931, expected=6.000000
# predicted=4.713208, expected=2.000000
# predicted=2.007237, expected=11.000000
# predicted=8.876552, expected=1.000000
# predicted=1.450031, expected=0.000000
# predicted=1.473590, expected=2.000000
# predicted=1.715517, expected=3.000000
# predicted=3.978609, expected=42.000000
# predicted=32.131133, expected=187.000000
# predicted=143.822854, expected=6.000000
# predicted=18.282851, expected=2.000000
# predicted=11.346258, expected=2.000000
# predicted=5.739070, expected=1.000000
# predicted=28.195305, expected=7.000000
# predicted=6.297088, expected=0.000000
# predicted=0.742984, expected=6.000000
# predicted=5.165815, expected=20.000000
# predicted=15.518647, expected=250.000000
# predicted=191.238450, expected=459.000000
# predicted=362.571267, expected=2.000000
# predicted=42.780493, expected=11.000000
# predicted=31.690138, expected=9.000000
# predicted=38.334614, expected=1.000000
# predicted=68.827222, expected=2.000000
# predicted=2.185113, expected=83.000000
# predicted=64.312829, expected=132.000000
# predicted=106.073751, expected=0.000000
# predicted=12.377085, expected=25.000000
# predicted=24.874613, expected=37.000000
# predicted=39.914664, expected=8.000000
# predicted=28.826967, expected=6.000000
# predicted=6.594131, expected=235.000000
# predicted=181.335191, expected=136.000000
# predicted=122.524793, expected=1.000000
# predicted=22.115385, expected=0.000000
# predicted=4.961611, expected=1.000000
# predicted=33.409590, expected=3.000000
# predicted=22.160996, expected=1.000000
# predicted=1.133873, expected=1.000000
# predicted=0.956276, expected=2.000000
# predicted=1.729883, expected=1.000000
# predicted=1.352600, expected=2.000000
# predicted=1.805893, expected=3.000000
# predicted=2.557829, expected=4.000000
# predicted=3.582827, expected=90.000000
# predicted=68.447639, expected=158.000000
# predicted=125.178773, expected=8.000000
# predicted=20.618597, expected=5.000000
# predicted=11.798305, expected=0.000000
# predicted=11.880283, expected=0.000000
# predicted=23.215126, expected=15.000000
# predicted=12.426965, expected=21.000000
# predicted=17.490752, expected=1.000000
# predicted=2.796286, expected=1.000000
# predicted=1.701964, expected=1.000000
# predicted=2.794218, expected=5.000000
# predicted=6.938024, expected=4.000000
# predicted=3.507196, expected=0.000000
# predicted=0.631794, expected=2.000000
# predicted=1.797604, expected=0.000000
# predicted=0.801246, expected=5.000000
# predicted=4.459820, expected=14.000000
# predicted=10.845521, expected=530.000000
# predicted=401.432707, expected=1391.000000
# predicted=1082.736355, expected=1.000000
# predicted=112.848591, expected=1.000000
# predicted=67.357587, expected=3.000000
# predicted=62.410037, expected=1.000000
# predicted=203.985660, expected=13.000000
# predicted=10.159618, expected=45.000000
# predicted=34.914048, expected=1.000000
# predicted=4.576506, expected=27.000000
# predicted=22.723875, expected=1.000000
# predicted=3.782058, expected=1.000000
# predicted=8.750465, expected=0.000000
# predicted=-0.078465, expected=2.000000
# predicted=5.488617, expected=4.000000
# predicted=3.273944, expected=4.000000
# predicted=3.510039, expected=1.000000
# predicted=1.177075, expected=11.000000
# predicted=8.809755, expected=7.000000
# predicted=6.536289, expected=3.000000
# predicted=3.822785, expected=0.000000
# predicted=0.548817, expected=0.000000
# predicted=1.671480, expected=29.000000
# predicted=22.872824, expected=51.000000
# predicted=40.692241, expected=8.000000
# predicted=10.616643, expected=9.000000
# predicted=9.524313, expected=1.000000
# predicted=5.307460, expected=1.000000
# predicted=8.618974, expected=2.000000
# predicted=2.676803, expected=2.000000
# predicted=2.983051, expected=3.000000
# predicted=2.621387, expected=7.000000
# predicted=5.688776, expected=0.000000
# predicted=0.845203, expected=2.000000
# predicted=2.121792, expected=2.000000
# predicted=1.981573, expected=5.000000
# predicted=5.019068, expected=3.000000
# predicted=2.645126, expected=8.000000
# predicted=6.742839, expected=191.000000
# predicted=145.031899, expected=2.000000
# predicted=14.206570, expected=7.000000
# predicted=15.505407, expected=0.000000
# predicted=-0.683193, expected=0.000000
# predicted=28.208241, expected=0.000000
# predicted=0.204644, expected=5.000000
# predicted=4.795421, expected=0.000000
# predicted=0.303453, expected=17.000000
# predicted=13.086755, expected=37.000000
# predicted=28.896669, expected=55.000000
# predicted=45.357824, expected=98.000000
# predicted=78.987134, expected=2.000000
# predicted=12.290691, expected=7.000000
# predicted=15.129035, expected=9.000000
# predicted=14.127059, expected=6.000000
# predicted=19.710463, expected=7.000000
# predicted=6.312390, expected=827.000000
# predicted=625.845588, expected=1548.000000
# predicted=1220.208861, expected=2.000000
# predicted=138.546404, expected=12.000000
# predicted=79.030952, expected=6.000000
# predicted=106.785601, expected=10.000000
# predicted=234.424318, expected=1.000000
# predicted=1.810959, expected=7.000000
# predicted=7.531866, expected=0.000000
# predicted=1.227151, expected=0.000000
# predicted=1.804699, expected=0.000000
# Test MSE: 490615.495

# %%
#plot model prediction compared with test
fig = plt.figure(figsize=(20,5))

plt.plot(test)
plt.plot(predictions, color='red')
plt.show()

# %%
# forecast 7 days
fc, se, conf = model_fit.forecast(7, alpha=0.05)

# make as pandas series
fc_series = pd.Series(fc, index=('2018-09-26','2018-09-27','2018-09-28','2018-09-29','2018-09-30','2018-10-01','2018-10-02'))
lower_series = pd.Series(conf[:, 0], index=('2018-09-26','2018-09-27','2018-09-28','2018-09-29','2018-09-30','2018-10-01','2018-10-02'))
upper_series = pd.Series(conf[:, 1], index=('2018-09-26','2018-09-27','2018-09-28','2018-09-29','2018-09-30','2018-10-01','2018-10-02'))

# plot
plt.figure(figsize=(12,2), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(fc_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
# forecast 14 days
fc, se, conf = model_fit.forecast(14, alpha=0.05)

# make as pandas series
fc_series = pd.Series(fc, 
                      index=('2018-09-26','2018-09-27','2018-09-28','2018-09-29','2018-09-30','2018-10-01','2018-10-02',
                             '2018-10-03','2018-10-04','2018-10-05','2018-10-06','2018-10-07','2018-10-08','2018-10-09'))
lower_series = pd.Series(conf[:, 0], 
                         index=('2018-09-26','2018-09-27','2018-09-28','2018-09-29','2018-09-30','2018-10-01','2018-10-02',
                             '2018-10-03','2018-10-04','2018-10-05','2018-10-06','2018-10-07','2018-10-08','2018-10-09'))
upper_series = pd.Series(conf[:, 1], 
                         index=('2018-09-26','2018-09-27','2018-09-28','2018-09-29','2018-09-30','2018-10-01','2018-10-02',
                             '2018-10-03','2018-10-04','2018-10-05','2018-10-06','2018-10-07','2018-10-08','2018-10-09'))

# plot
plt.figure(figsize=(12,2), dpi=100)
plt.plot(train, label='training')
plt.plot(test, label='actual')
plt.plot(fc_series, label='forecast')
plt.fill_between(fc_series.index, lower_series, upper_series, 
                 color='k', alpha=.15)
plt.title('Forecast vs Actuals')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
#the impressions for Mobile channel at 2018-10-02 is 1.620175, at 2018-10-09 is 1.688434
fc_series
# Out:
# 2018-09-26    1.804699
# 2018-09-27    1.420678
# 2018-09-28    2.203231
# 2018-09-29    1.841132
# 2018-09-30    1.573274
# 2018-10-01    1.657311
# 2018-10-02    1.620175
# 2018-10-03    1.702276
# 2018-10-04    1.716765
# 2018-10-05    1.690648
# 2018-10-06    1.688740
# 2018-10-07    1.680014
# 2018-10-08    1.683780
# 2018-10-09    1.688434
# dtype: float64
